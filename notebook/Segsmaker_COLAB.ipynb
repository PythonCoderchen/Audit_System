# %% [markdown]
# <a href="https://github.com/gutris1/segsmaker">
#   <img alt="GitHub repo" src="https://img.shields.io/badge/GitHub-6e5494?style=for-the-badge&logo=github&logoColor=white"/>
# </a><br>
#
# *   get your civitai api key from [here](https://civitai.com/user/account)

# %%
# @title <b><font color='orange'>WebUI Installer</font></b> {"display-mode":"form"}

Webui = 'A1111' # @param ["A1111", "Forge", "ReForge", "Forge-Classic", "ComfyUI", "SwarmUI"]
Civitai___Key = '9d3a03f3fb69154b92af1f7cf559fd29' # @param { type: "string", placeholder: "Your Civitai API Key (required)" }
HF_Read_Token = '' # @param { type: "string", placeholder: "Your Huggingface READ Token (optional)" }
Mount__GDrive = 'Yes' # @param ["Yes", "No"]

if Mount__GDrive == 'Yes':
    from google.colab import drive
    drive.mount('/content/drive')

# !curl -sLo /content/setup.py https://github.com/gutris1/segsmaker/raw/main/script/KC/setup.py
# %run /content/setup.py --webui="$Webui" --civitai_key="$Civitai___Key" --hf_read_token="$HF_Read_Token"

if Mount__GDrive == 'Yes':
    from pathlib import Path

    d = Path('/content/drive/MyDrive/Segsmaker')

    for n, p in {'checkpoint': CKPT, 'lora': LORA, 'vae': VAE, 'embeddings': Embeddings}.items():
        f = d / n
        f.mkdir(parents=True, exist_ok=True)
        s = p / f'drive-{n}'
        s.symlink_to(f, target_is_directory=True)

    # !rm -rf $WebUI_Output
    o = d / {'ComfyUI': 'comfyui-output', 'SwarmUI': 'swarmui-output'}.get(Webui, 'output')
    o.mkdir(parents=True, exist_ok=True)
    WebUI_Output.symlink_to(o, target_is_directory=True)

    if Webui not in {'ComfyUI', 'SwarmUI'}:
        cc = WebUI / 'cache'
        # !rm -rf $cc
        c = d / 'cache'
        c.mkdir(parents=True, exist_ok=True)
        cc.symlink_to(c, target_is_directory=True)
# Out:
# Mounted at /content/drive
# Output()
# Output()

# %%
''' These are placeholders for commands with empty inputs. '''
''' Replace them with actual values or skip/delete this cell. '''


''' SD Extensions / ComfyUI Custom Nodes '''
# %cd -q $Extensions
# !git clone

''' VAE '''
# %cd -q $VAE
# %download

''' Embeddings '''
# %cd -q $Embeddings
# %download

''' Upscalers '''
# %cd -q $Upscalers
# %download

''' FLUX Unet '''
# %cd -q $UNET
# %download

''' FLUX Clip '''
# %cd -q $CLIP
# %download
# Out:
# fatal: You must specify a repository to clone.
#
# usage: git clone [<options>] [--] <repo> [<dir>]
#
#     -v, --verbose         be more verbose
#     -q, --quiet           be more quiet
#     --progress            force progress reporting
#     --reject-shallow      don't clone shallow repository
#     -n, --no-checkout     don't create a checkout
#     --bare                create a bare repository
#     --mirror              create a mirror repository (implies bare)
#     -l, --local           to clone from a local repository
#     --no-hardlinks        don't use local hardlinks, always copy
#     -s, --shared          setup as shared repository
#     --recurse-submodules[=<pathspec>]
#                           initialize submodules in the clone
#     --recursive ...       alias of --recurse-submodules
#     -j, --jobs <n>        number of submodules cloned in parallel
#     --template <template-directory>
#                           directory from which templates will be used
#     --reference <repo>    reference repository
#     --reference-if-able <repo>
#                           reference repository
#     --dissociate          use --reference only while cloning
#     -o, --origin <name>   use <name> instead of 'origin' to track upstream
#     -b, --branch <branch>
#                           checkout <branch> instead of the remote's HEAD
#     -u, --upload-pack <path>
#                           path to git-upload-pack on the remote
#     --depth <depth>       create a shallow clone of that depth
#     --shallow-since <time>
#                           create a shallow clone since a specific time
#     --shallow-exclude <revision>
#                           deepen history of shallow clone, excluding rev
#     --single-branch       clone only one branch, HEAD or --branch
#     --no-tags             don't clone any tags, and make later fetches not to follow them
#     --shallow-submodules  any cloned submodules will be shallow
#     --separate-git-dir <gitdir>
#                           separate git dir from working tree
#     -c, --config <key=value>
#                           set config inside the new repository
#     --server-option <server-specific>
#                           option to transmit
#     -4, --ipv4            use IPv4 addresses only
#     -6, --ipv6            use IPv6 addresses only
#     --filter <args>       object filtering
#     --remote-submodules   any cloned submodules will use their remote-tracking branch
#     --sparse              initialize sparse-checkout file to include only files at root
#
#   missing URL, downloading nothing
#   missing URL, downloading nothing
#   missing URL, downloading nothing
# [Errno 2] No such file or directory: 'None'
#   missing URL, downloading nothing
# [Errno 2] No such file or directory: 'None'
#   missing URL, downloading nothing

# %%
''' Checkpoint '''
# %cd -q $CKPT
# %download https://huggingface.co/pantat88/back_up/resolve/main/bigblu25dmix25DStyle_v10.safetensors

''' LoRA '''
# %cd -q $LORA
# %download https://civitai.com/models/122359/detail-tweaker-xl
# %download https://civitai.com/models/669571/pony-add-more-details details-add-more-pony.safetensors
# Out:
#  【#402b4d 6.3GiB/6.4GiB(97%) CN:16 DL:170MiB】
#   402b4d|OK  |   195MiB/s|/content/A1111/models/Stable-diffusion/bigblu25dmix25DStyle_v10.safetensors
#  【#f4e492 73MiB/217MiB(33%) CN:16 DL:174MiB】
#   f4e492|OK  |   207MiB/s|/content/A1111/models/Lora/add-detail-xl.safetensors
#  【#d061ea 174MiB/217MiB(80%) CN:16 DL:214MiB】
#   d061ea|OK  |   188MiB/s|/content/A1111/models/Lora/details-add-more-pony.safetensors

# %%
# %cd -q $CKPT
# %download https://civitai.com/api/download/models/325142?type=Model&format=SafeTensor&size=pruned&fp=fp16
# Out:
#  【#2ed4e5 2.1GiB/2.1GiB(99%) CN:1 DL:146MiB】
#   2ed4e5|OK  |   150MiB/s|/content/A1111/models/Stable-diffusion/realisian_v60.safetensors

# %%
''' Controlnet '''
# %run $Controlnet_Widget
# Out:
# <style>:root {
#   --cn-gradient-bg: linear-gradient(to right,
#     rgb(255, 0, 0), rgb(255, 0, 25), rgb(255, 0, 50), rgb(255, 0, 75),
#     rgb(255, 0, 100), rgb(255, 0, 125), rgb(255, 0, 150), rgb(255, 0, 175),
#     rgb(255, 0, 200), rgb(255, 0, 225), rgb(255, 0, 255), rgb(225, 0, 255),
#     rgb(200, 0, 255), rgb(175, 0, 255), rgb(150, 0, 255), rgb(125, 0, 255),
#     rgb(100, 0, 255), rgb(75, 0, 255), rgb(50, 0, 255), rgb(25, 0, 255),
#     rgb(0, 0, 255), rgb(0, 25, 255), rgb(0, 50, 255), rgb(0, 75, 255),
#     rgb(0, 100, 255), rgb(0, 125, 255), rgb(0, 150, 255), rgb(0, 175, 255),
#     rgb(0, 200, 255), rgb(0, 225, 255), rgb(0, 255, 255), rgb(0, 255, 225),
#     rgb(0, 255, 200), rgb(0, 255, 175), rgb(0, 255, 150), rgb(0, 255, 125),
#     rgb(0, 255, 100), rgb(0, 255, 75), rgb(0, 255, 50), rgb(0, 255, 25),
#     rgb(0, 255, 0), rgb(25, 255, 0), rgb(50, 255, 0), rgb(75, 255, 0),
#     rgb(100, 255, 0), rgb(125, 255, 0), rgb(150, 255, 0), rgb(175, 255, 0),
#     rgb(200, 255, 0), rgb(225, 255, 0), rgb(255, 255, 0), rgb(255, 225, 0),
#     rgb(255, 200, 0), rgb(255, 175, 0), rgb(255, 150, 0), rgb(255, 125, 0),
#     rgb(255, 100, 0), rgb(255, 75, 0), rgb(255, 50, 0), rgb(255, 25, 0),
#     rgb(255, 0, 0));
# }
#
# .cn-panel {
#   border: 0px solid transparent;
#   border-radius: 30px;
#   margin: 0;
#   background-color: transparent;
#   animation: slide-blur-panel 1s;
#   overflow: visible !important;
# }
#
# @keyframes slide-blur-panel {
#   from {
#     height: 0px;
#     opacity: 0;
#     filter: blur(30px);
#   }
#   to {
#     height: 405px;
#     opacity: 1;
#     filter: blur(0px);
#   }
# }
#
# .btn-cn-15, .btn-cn-xl {
#   height: auto;
#   cursor: pointer;
#   border-width: 0px;
#   filter: brightness(50%) blur(5px);
#   background-size: cover;
#   background-position: center;
#   background-repeat: no-repeat;
#   border-radius: 3px;
#   position: relative;
#   overflow: hidden;
#   -webkit-mask: linear-gradient(to left, transparent, #000 1px);
#   width: 70%;
#   box-shadow: inset 0 0 10px 7px #000 !important;
#   transition: 0.4s ease;
# }
#
# .btn-cn-15 {
#   background-image: url('https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/5f06d0e2-5959-4c31-be80-546735970d76/original=true,quality=90/00014-1506.jpeg');
# }
#
# .btn-cn-xl {
#   background-image: url('https://i.imgur.com/giAg91c.jpg');
# }
#
# .btn-cn-15::after, .btn-cn-xl::after {
#   font-family: 'Times New Roman', serif;
#   text-align: center;
#   position: absolute;
#   bottom: 0px;
#   left: -10px;
#   color: white;
#   font-size: 40px;
#   background-color: rgba(0, 0, 0, 0.7);
#   padding: 10px;
#   display: block;
#   border-radius: 0px;
#   width: 100%;
#   filter: drop-shadow(0 0 10px #000);
#   box-shadow: 0 0 10px 1px #000;
# }
#
# .btn-cn-15::after {
#   content: 'SD 1.5';
# }
# .btn-cn-xl::after {
#   content: 'SD XL';
# }
#
# .btn-cn-15:hover, .btn-cn-xl:hover {
#   width: 100%;
#   border-width: 0px;
#   filter: brightness(100%) blur(0);
# }
#
# @keyframes Undress15 {
#   0% {
#     max-height: 0;
#     opacity: 0;
#     filter: blur(10px);
#   }
#   100% {
#     max-height: 490px;
#     opacity: 1;
#     filter: blur(0px);
#   }
# }
#
# @keyframes UndressXL {
#   0% {
#     max-height: 0;
#     opacity: 0;
#     filter: blur(10px);
#   }
#   100% {
#     max-height: 580px;
#     opacity: 1;
#     filter: blur(0px);
#   }
# }
#
# .cn-xl, .cn-15 {
#   position: relative;
#   border: 3px solid transparent;
#   border-radius: 30px;
#   margin: 0;
#   max-height: 0;
#   background-color: transparent;
#   background-size: cover;
#   background-position: center;
# }
#
# .cn-xl {
#   animation: UndressXL 1s forwards ease-out, BorderPulse 15s infinite;
# }
# .cn-15 {
#   animation: Undress15 1s forwards ease-out, BorderPulse 15s infinite;
# }
#
# .cn-xl::before, .cn-15::before {
#   content: '';
#   position: absolute;
#   top: 0;
#   left: 0;
#   right: 0;
#   bottom: 0;
#   background-image: url('https://i.imgur.com/5Mkdrpw.jpg');
#   background-size: cover;
#   background-position: center;
#   filter: blur(0px);
#   transition: all 0.5s ease;
#   border-radius: 28px;
#   z-index: -1;
#   background-color: rgba(0, 0, 0, 0.5);
#   mix-blend-mode: multiply;
# }
#
# .cn-xl:hover::before, .cn-15:hover::before {
#   filter: blur(10px);
# }
#
# .widget-container {
#   margin: 0;
#   overflow: hidden;
#   position: relative;
# }
#
# .widget-container .checkbox_layout_15,
# .widget-container .checkbox_layout_xl {
#   top: -40px !important;
# }
#
# .widget-container .widget-box {
#   overflow: visible !important;
# }
#
# .cn-xl .download-button-xl,
# .cn-xl .select-all-button-xl,
# .cn-xl .unselect-all-button-xl,
# .cn-15 .download-button-15,
# .cn-15 .select-all-button-15,
# .cn-15 .unselect-all-button-15 {
#   display: flex;
#   outline: none !important;
#   font-weight: bold;
#   position: relative;
#   margin: 0;
#   background-color: transparent;
#   text-align: center;
#   color: cyan;
#   border: 2px solid transparent;
#   border-radius: 100px;
#   height: 40px;
#   font-size: 16px;
#   padding: 0 10px;
#   z-index: 1;
#   justify-content: center;
#   align-items: center;
#   transition: 0.3s ease;
# }
#
# .download-button-15,
# .select-all-button-15,
# .unselect-all-button-15 {
#   top: 415px;
# }
#
# .download-button-xl,
# .select-all-button-xl,
# .unselect-all-button-xl {
#   top: 505px;
# }
#
# .download-button-15,
# .download-button-xl {
#   left: -40px;
#   margin-right: 0px;
#   margin-bottom: 0px;
#   margin-left: 0px;
# }
#
# .select-all-button-15,
# .select-all-button-xl {
#   margin-right: 0px;
#   margin-bottom: 0px;
#   margin-left: 0px;
# }
#
# .unselect-all-button-15,
# .unselect-all-button-xl {
#   left: -40px;
#   margin-right: 0px;
#   margin-bottom: 0px;
#   margin-left: 0px;
# }
#
# .download-button-15:hover,
# .select-all-button-15:hover,
# .unselect-all-button-15:hover,
# .download-button-xl:hover,
# .select-all-button-xl:hover,
# .unselect-all-button-xl:hover {
#   border-color: cyan;
#   filter: drop-shadow(0 0 10px #275EFE);
#   box-shadow: 0 0 10px 1px cyan !important;
#   background-color: cyan;
#   color: #000;
# }
#
# .bottom-box-15, .bottom-box-xl {
#   display: block;
#   user-select: none;
#   -webkit-user-select: none;
#   position: absolute;
#   pointer-events: none;
#   transform: translateX(-50%);
#   height: 55px;
#   border: 3px solid transparent;
#   border-radius: 30px;
#   background-color: rgba(0, 0, 0, 0.9);
#   padding: 0px;
#   animation: BorderPulse 15s infinite;
# }
#
# .bottom-box-15 {
#   bottom: -425px;
#   left: 49.5%;
#   width: 530px;
# }
#
# .bottom-box-xl {
#   bottom: -515px;
#   left: 49.5%;
#   width: 600px;
# }
#
# .checkbox input {
#   --active: #275EFE;
#   --active-inner: #fff;
#   --focus: 2px rgba(39, 94, 254, .3);
#   --border: #BBC1E1;
#   --border-hover: #275EFE;
#   --background: #fff;
#   --disabled: #F6F8FF;
#   --disabled-inner: #E1E6F9;
#   -webkit-appearance: none;
#   -moz-appearance: none;
#   width: 15px;
#   height: 15px;
#   right: 0px;
#   border-radius: 0;
#   margin-top: -3px !important;
#   margin-right: 10px !important;
#   margin-bottom: 0 !important;
#   margin-left: 0 !important;
#   vertical-align: middle;
#   cursor: pointer;
#   border: 0;
#   background-color: rgba(0, 0, 0, 0.5);
#   transition: background-color 0.3s ease, filter 0.3s ease, box-shadow 0.3s ease;
#   position: relative;
#   transform: rotate(45deg);
# }
#
# .checkbox input:checked {
#   border-color: #275EFE;
#   background-color: #275EFE;
#   background-image: radial-gradient(circle, white 30%, transparent 40%);
#   filter: drop-shadow(0 0 10px #275EFE);
#   box-shadow: 0 0 1px 1px #000, 0 0 10px 1px #275EFE;
# }
#
# .checkbox input:checked:hover {
#   background-color: cyan;
#   filter: drop-shadow(0 0 10px cyan);
#   box-shadow: 0 0 10px 1px cyan;
# }
#
# .checkbox input:not(:checked):hover {
#   border-color: #275EFE;
#   background-image: none;
#   filter: drop-shadow(0 0 10px #275EFE);
#   box-shadow: 0 0 10px 1px #275EFE;
# }
#
# .checkbox label {
#   overflow: visible;
#   position: absolute;
#   text-align: left;
#   font-family: 'Roboto Mono', monospace;
#   font-size: 12px;
#   font-weight: bold;
#   color: black;
#   vertical-align: middle;
#   width: max-content;
#   margin: 0;
#   padding: 0 15px;
#   margin-left: -5px;
#   border: 2px solid transparent;
# }
#
# .checkbox label:hover {
#   border-radius: 1rem;
#   color: cyan;
#   background-color: rgba(0, 0, 0, 0.6);
#   border: 2px solid rgba(0, 0, 0, 0.6);
#   cursor: pointer;
#   filter: drop-shadow(0 0 10px cyan);
#   box-shadow: 0 0 3px 0 cyan;
#   animation: BorderPulse 7s infinite;
# }
#
# @keyframes s
# HBox(children=(Button(style=ButtonStyle(), _dom_classes=('btn-cn-15',)), Button(style=ButtonStyle(), _dom_clas…
# Box(children=(HBox(children=(Button(description='Select All', layout=Layout(left='15px', width='130px'), style…
# Box(children=(HBox(children=(Button(description='Select All', layout=Layout(left='30px'), style=ButtonStyle(),…
# Output()

# %% [markdown]
# ## Launcher
# args list :
# -  **A1111** = `--xformers`
# - **Forge** = `--disable-xformers --opt-sdp-attention --cuda-stream`
# - **ReForge** = `--xformers --cuda-stream`
# - **Forge-Classic** = `--xformers --cuda-stream --persistent-patches`
# - **ComfyUI** = `--dont-print-server --use-pytorch-cross-attention`
# - **SwarmUI** = `--launch_mode none`
# <br><br>
#
# For ComfyUI, add `--skip-comfyui-check` to skip checking the main requirements and custom node dependencies
#
# Add **--N=ngrok_token** to start NGROK tunnel<br>
# Add **--Z=zrok_token** to start ZROK tunnel

# %%
# %cd -q $WebUI
# %run segsmaker.py --xformers
# Out:
# Python 3.10.15 (main, Oct 16 2024, 04:37:23) [Clang 18.1.8 ]
# Version: v1.10.1
# Commit hash: 82a973c04367123ae98bd9abdf80d9eda9b910e2
# Installing None
# Launching Web UI with arguments: --xformers --enable-insecure-extension-access --disable-console-progressbars --theme dark
# [-] ADetailer initialized. version: 25.3.0, num models: 10
# Tag Autocomplete: Could not locate model-keyword extension, Lora trigger word completion will be limited to those added through the extra networks menu.
# ● CivitAI Browser+: Aria2 RPC started
# ▶ SD-Hub: v11
# ControlNet preprocessor location: /content/A1111/extensions/sd-webui-controlnet/annotator/downloads
# 2025-09-24 08:05:40,875 - ControlNet - INFO - ControlNet v1.1.455
# Loading weights [7285bd92b3] from /content/A1111/models/Stable-diffusion/bigblu25dmix25DStyle_v10.safetensors
# 2025-09-24 08:05:42,599 - ControlNet - INFO - ControlNet UI callback registered.
# Creating model from config: /content/A1111/repositories/generative-models/configs/inference/sd_xl_base.yaml
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# IIB Database file has been successfully backed up to the backup folder.
# GenParamsGetter detected!
# GenParamsGetter detected!
# Startup time: 36.3s (prepare environment: 16.0s, import torch: 7.6s, import gradio: 2.1s, setup paths: 1.4s, initialize shared: 0.2s, other imports: 0.5s, list SD models: 0.5s, load scripts: 4.5s, create ui: 2.5s, gradio launch: 0.8s, app_started_callback: 0.2s).
#
# 🟢 Gradio : https://60701503918cf1283c.gradio.live
#
# 🟢 Pinggy : https://gfbju-34-125-133-113.a.free.pinggy.link
#
# 🟢 Cloudflared : http://find-poultry-patricia-cancer.trycloudflare.com
#
# Calculating sha256 for /content/A1111/models/Stable-diffusion/realisian_v60.safetensors: aa7b94cdfc47576d9d514f3bada704ae04d2fe004ea05d7c5cfc80018851aed3
# ● Civitai: Checking resources for missing info files
# ● Civitai: Updated 1 info files
# ● Civitai: Checking resources for missing preview image
# ● Civitai: Updated 1 preview images
# Applying attention optimization: xformers... done.
# Model loaded in 22.3s (load weights from disk: 1.6s, create model: 1.9s, apply weights to model: 17.5s, apply half(): 0.2s, load textual inversion embeddings: 0.2s, calculate empty prompt: 0.7s).
# Reusing loaded model bigblu25dmix25DStyle_v10.safetensors [7285bd92b3] to load realisian_v60.safetensors
# Loading weights [aa7b94cdfc] from /content/A1111/models/Stable-diffusion/realisian_v60.safetensors
# Creating model from config: /content/A1111/configs/v1-inference.yaml
# Applying attention optimization: xformers... done.
# Model loaded in 11.0s (create model: 0.5s, apply weights to model: 9.7s, apply half(): 0.1s, load textual inversion embeddings: 0.3s, calculate empty prompt: 0.2s).
# 100% 20/20 [00:03<00:00,  5.04it/s]
# Interrupted with signal 2 in <frame at 0x5664b0174280, file '/GUTRIS1/lib/python3.10/threading.py', line 324, code wait>
#
# Gradio, Pinggy, Cloudflared Died.
